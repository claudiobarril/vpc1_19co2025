# %% [markdown]
# # TP 3 - Parte 1

# %%
import util_cb_2 as utils

# %%
utils.run_matching_pipeline("material/template/pattern.png", "material/images/COCA-COLA-LOGO.jpg")
utils.run_matching_pipeline("material/template/pattern.png", "material/images/coca_logo_1.png")
utils.run_matching_pipeline("material/template/pattern.png", "material/images/coca_logo_2.png")
utils.run_matching_pipeline("material/template/pattern.png", "material/images/coca_retro_1.png")
utils.run_matching_pipeline("material/template/pattern.png", "material/images/coca_retro_2.png")
utils.run_matching_pipeline("material/template/pattern.png", "material/images/logo_1.png")
utils.run_matching_pipeline("material/template/pattern.png", "material/images/coca.png")
# Out:
# Mejor variante: invertido con 28 matches.
# Mejor variante: invertido con 39 matches.
# Mejor variante: invertido con 35 matches.
# Mejor variante: normal con 27 matches.
# Mejor variante: invertido con 19 matches.
# Mejor variante: invertido con 34 matches.
# Mejor variante: invertido con 47 matches.
